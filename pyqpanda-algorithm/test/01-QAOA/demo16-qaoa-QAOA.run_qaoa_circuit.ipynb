# %%
import sys
from pathlib import Path
sys.path.append((Path.cwd().parent.parent).__str__())

# %%
import sympy as sp
from pyqpanda_alg.QAOA.qaoa import *

# %%
vars = sp.symbols('x0:3')
f = 2*vars[0]*vars[1] + 3*vars[2] - 1
qaoa_f = QAOA(f)

gammas = [1, 2]
betas = [2, 1]

qaoa_result = qaoa_f.run_qaoa_circuit(gammas, betas, -1)
print(qaoa_result)
qaoa_result = qaoa_f.run_qaoa_circuit(gammas, betas, 500)
print(qaoa_result)
# Out:
# {'000': 0.1564473274825159, '001': 0.15694780254308643, '010': 0.15694780254308646, '011': 0.13737646367646342, '100': 0.10098616641144186, '101': 0.101309221196492, '110': 0.10130922119649201, '111': 0.08867599495042273}
# {'000': 0.146, '001': 0.138, '010': 0.19, '011': 0.15, '100': 0.098, '101': 0.094, '110': 0.11, '111': 0.074}
