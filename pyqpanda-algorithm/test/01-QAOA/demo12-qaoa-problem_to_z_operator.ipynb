# %%
import sys
from pathlib import Path
sys.path.append((Path.cwd().parent.parent).__str__())

# %%
import sympy as sp
from pyqpanda_alg.QAOA import qaoa
from pyqpanda3.hamiltonian import PauliOperator

# %%
vars = sp.symbols('x0:3')
f = 2*vars[0]*vars[1] + 3*vars[2] - 1
print(f)
# Out:
# 2*x0*x1 + 3*x2 - 1

# %%
hamiltonian = qaoa.problem_to_z_operator(f)
print(hamiltonian)
# Out:
# { qbit_total = 3, pauli_with_coef_s = { '':1 + 0j, 'Z2 ':-1.5 + 0j, 'Z1 ':-0.5 + 0j, 'Z0 ':-0.5 + 0j, 'Z0 Z1 ':0.5 + 0j, } }

# %%
hamiltonian = qaoa.problem_to_z_operator(f, norm=True)
print(hamiltonian)
# Out:
# { qbit_total = 3, pauli_with_coef_s = { '':1.25 + 0j, 'Z2 ':-1.875 + 0j, 'Z1 ':-0.625 + 0j, 'Z0 ':-0.625 + 0j, 'Z0 Z1 ':0.625 + 0j, } }
