# %%
import sys
from pathlib import Path
sys.path.append((Path.cwd().parent.parent).__str__())

# %%
from pyqpanda_alg.QAOA import qaoa
from pyqpanda3.hamiltonian import PauliOperator

# %%
operator_0 = qaoa.p_1(0)
print(operator_0)
operator_0 = operator_0.tensor(PauliOperator({"I1" : 1.0}))
print(operator_0)
# Out:
# { qbit_total = 1, pauli_with_coef_s = { '':0.5 + 0j, 'Z0 ':-0.5 + 0j, } }
# { qbit_total = 3, pauli_with_coef_s = { '':0.5 + 0j, 'Z0 ':-0.5 + 0j, } }

# %%
operator_1 = qaoa.p_1(1)
print(operator_1)
operator_1 = operator_1.tensor(PauliOperator({"I0" : 1.0}))
print(operator_1)
# Out:
# { qbit_total = 2, pauli_with_coef_s = { '':0.5 + 0j, 'Z1 ':-0.5 + 0j, } }
# { qbit_total = 3, pauli_with_coef_s = { '':0.5 + 0j, 'Z1 ':-0.5 + 0j, } }

# %%
operator_2 = qaoa.p_1(2)
print(operator_2)
# Out:
# { qbit_total = 3, pauli_with_coef_s = { '':0.5 + 0j, 'Z2 ':-0.5 + 0j, } }
