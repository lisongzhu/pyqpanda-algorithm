# %%
from pyqpanda_alg.QFinance import comparator, grover, QAE, QUBO, QSVD, class_qsvr, QmRMR, class_basic_sparecode
import numpy as np
from pyqpanda3.core import *
import matplotlib.pyplot as plts

# %%
m = CPUQVM()
prog = QProg()
prog << H(0) << H(1) << X(3)
# 量子态之间的比较，量子态0,1,2,3大于量子态2中的部分只有3，占四分之一，所以是0.25
cir = comparator.qubit_comparator([0, 1], [2, 3],  [4, 5], function='g')
prog << cir
m.run(prog, 1000)
prob_dict_result = m.result().get_prob_dict([5])
print(prob_dict_result)
# Out:
# {'0': 0.7500000000000003, '1': 0.2500000000000001}
