# %%
from pyqpanda_alg.QFinance import comparator, grover, QAE, QUBO, QSVD, class_qsvr, QmRMR, class_basic_sparecode
import numpy as np
from pyqpanda3.core import *
import matplotlib.pyplot as plt

# %%
'''
测试输出是否一致，或者输出是否只差-1倍
Returns:
'''
matrix = np.random.random(32).reshape([4, 8])
para = QSVD.SVD(matrix_in=matrix).QSVD_min()
qeig = QSVD.SVD(matrix_in=matrix).return_diag(para)
l1 = QSVD.SVD(matrix_in=matrix).max_eig('0', para, 0)
l2 = QSVD.SVD(matrix_in=matrix).max_eig('1', para, 0)

print(l1)
print(l2)
print(np.sort(np.diag(qeig)))
print("xx"*20)
u, s, v = np.linalg.svd(matrix)
print(u[:, 0])
print(v[0])
print(np.sort(s))
# Out:
# [0.44942794 0.36566428 0.55150672 0.6001204 ]
# [0.48679665 0.4441883  0.35353061 0.25236633 0.34896632 0.12450214
#  0.22028793 0.43731918]
# [0.50705806 0.65170803 1.0655952  2.7474434 ]
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# [-0.44942676 -0.36566485 -0.55150663 -0.60012102]
# [-0.48679712 -0.44418855 -0.35353212 -0.25236582 -0.34896737 -0.12450199
#  -0.22028613 -0.43731759]
# [0.50705806 0.65170803 1.0655952  2.7474434 ]
