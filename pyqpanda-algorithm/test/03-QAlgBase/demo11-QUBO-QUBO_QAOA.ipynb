# %%
import sympy as sp
import numpy as np
from pyqpanda_alg.QFinance import QUBO
from pyqpanda3.core import CPUQVM, QCircuit, QProg, TOFFOLI, X, Z, H, U1, RY

# %%
x0, x1, x2 = sp.symbols('x0 x1 x2')
function = -0.5 * x0 * x1 - 0.7 * x0 * x1 + 0.9 * x1 * x2 + 1.3 * x0 - x1 - 0.5 * x2
# find the minimum function value using QAOA
test2 = QUBO.QUBO_QAOA(function)
res2 = test2.run(layer=5, optimizer='SLSQP', optimizer_option={'options':{'eps':1e-3}})
print('result of QAOA: ', res2)
# Out:
# result of QAOA:  {'110': 0.5175963597392462, '010': 0.4600805346594895, '011': 0.010644996691900232, '000': 0.004250655489842041, '111': 0.00401328619482355, '001': 0.002672988368000342, '101': 0.0007091667960030419, '100': 3.201206069602482e-05}
