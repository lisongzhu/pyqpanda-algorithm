# %%
from pyqpanda_alg.QFinance import comparator, grover, QAE, QUBO, QSVD, class_qsvr, QmRMR, class_basic_sparecode
import numpy as np
from pyqpanda3.core import *
import matplotlib.pyplot as plt

# %%
m = CPUQVM()
prog = QProg()
prog << H(0) << H(1) << X(3)
# 和comparator.qubit_comparator一样
cir = comparator.qft_qubit_comparator([0, 1], [2, 3], [4], function='g')
prog << cir
m.run(prog, 1000)
prob_dict_result = m.result().get_prob_dict([4])
print(prob_dict_result)
# Out:
# {'0': 0.7500000000000007, '1': 0.2500000000000002}
