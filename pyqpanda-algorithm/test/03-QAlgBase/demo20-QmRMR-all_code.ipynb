# %%
from pyqpanda_alg.QFinance import comparator, grover, QAE, QUBO, QSVD, class_qsvr, QmRMR, class_basic_sparecode
import numpy as np
from pyqpanda3.core import *
import matplotlib.pyplot as plt

# %%
'''
画出来loss能下降就行,且choice_num中的1的数量和入参select_num一样就行
Returns:
'''
m = 6
u = np.random.random(m)
cor = np.random.random([m, m])
cor = (cor.T + cor)/2
ini_par = np.random.random(int(m/2)*m)*np.pi
loss, choice, dic = QmRMR.all_code.Feature_Selection(cor, u, 3).get_his_res(ini_par)
print(loss)
print(choice)
plt.plot(loss)
plt.show()
# Out:
# [5.642712224122517, 5.630429408378788, 5.629869047301971, 5.628854160355445, 5.628027954319579, 5.625562262273455, 5.6242072906223175, 5.623722533850787, 5.606759153544085, 5.59767102184443, 5.593675705559308, 5.591273666226366, 5.5896486302131985, 5.589647482837648, 5.584130507019179, 5.584125700761273, 5.582110197011579, 5.582106450744807, 5.582063432334457, 5.577354581552327, 5.570277861596098, 5.570275374927541, 5.565457442709929, 5.559453021170284, 5.55886158180465, 5.557286231757052, 5.556277929104053, 5.556265429528627, 5.554590847685162, 5.55389475372685, 5.553816335207856, 5.553358095553904, 5.552983862661792, 5.552652563845493, 5.552545482747563, 5.552189927165963, 5.551902067860427, 5.55156147852105, 5.550436887939671, 5.547280921354582, 5.54496640215163, 5.544705511681143, 5.544638047911912, 5.544537048333136, 5.538514319139442, 5.538342006609762, 5.537882996298546, 5.537542104466727, 5.531655986871845, 5.531078199098434, 5.530693938383004, 5.527152937282835, 5.5268103098
# ...
