# %%
import sys
sys.path.append('/home/bylz/wh/GitData/pyqpanda-algorithm/pyqpanda-algorithm')

# %%
from pyqpanda3.core import CPUQVM, QProg, draw_qprog
from pyqpanda_alg.HHL import HHL_solve_linear_equations, expand_linear_equations, build_HHL_circuit

# %%
A = [2.0, 1.0, 0, 1.0, 2.0, 1.0, 0, 1.0, 2.0]
b = [1.0, 1.0, 1.0]
result = expand_linear_equations(A, b)
print(result)
print(result[0])
print(result[1])
print(A)
print(b)
# Out:
# [[(2+0j), (1+0j), 0j, 0j, (1+0j), (2+0j), (1+0j), 0j, 0j, (1+0j), (2+0j), 0j, 0j, 0j, 0j, 0j], [1.0, 1.0, 1.0, 0.0]]
# [(2+0j), (1+0j), 0j, 0j, (1+0j), (2+0j), (1+0j), 0j, 0j, (1+0j), (2+0j), 0j, 0j, 0j, 0j, 0j]
# [1.0, 1.0, 1.0, 0.0]
# [2.0, 1.0, 0, 1.0, 2.0, 1.0, 0, 1.0, 2.0]
# [1.0, 1.0, 1.0]
