# %%
import sys
sys.path.append('/home/bylz/wh/GitData/pyqpanda-algorithm/pyqpanda-algorithm')

# %%
from pyqpanda3.core import CPUQVM, QProg, draw_qprog
from pyqpanda_alg.HHL import HHL_solve_linear_equations, expand_linear_equations, build_HHL_circuit

# %%
A=[1.0, 0, 0, 1.0]
b=[0.6, 0.8]
result = HHL_solve_linear_equations(A, b, 1)

#print HHL result
for key in result:
    print(key)
    
print(type(result))
    
# 精确解 = [0.6 0.8]
# Out:
# (0.5999999999999989+0j)
# (0.7999999999999985+0j)
# <class 'list'>

# %%
A=[1.0, 0, 0, 2.0]
b=[1.0, 1.0]
result = HHL_solve_linear_equations(A, b, 1)

#print HHL result
for key in result:
    print(key)
    
# 精确解 = [1.0 0.5]
# Out:
# (0.9999999999999947+0j)
# (0.4999999999999974+0j)

# %%
# （4×4 对角 Herm 矩阵）
A=[2, 0, 0, 0, 0, 3, 0, 0, 0, 0, 4, 0, 0, 0, 0, 5]
b=[2, 3, 4, 5]
result = HHL_solve_linear_equations(A, b, 1)

#print HHL result
for key in result:
    print(key)
    
# 精确解 = [1, 1, 1, 1]
# Out:
# (0.9999999999999885+0j)
# (1.000000000000016+0j)
# (0.9999999999999886+0j)
# (1.000000000000016+0j)

# %%
# （4×4 三对角 Hermitian 矩阵）
A=[4, 1, 0, 0, 1, 4, 1, 0, 0, 1, 4, 1, 0, 0, 1, 4]
b=[5, 6, 6, 5]
result = HHL_solve_linear_equations(A, b, 1)

#print HHL result
for key in result:
    print(key)
    
# 精确解 = [1, 1, 1, 1]
# Out:
# (0.9994116909575668+0j)
# (0.9979287082313798+0j)
# (0.9979287082313811+0j)
# (0.9994116909575663+0j)

# %%
# （4×4 一般 Hermitian 矩阵）
A=[2, 1, 0, 1, 1, 3, 1, 0, 0, 1, 4, 1, 1, 0, 1, 5]
b=[4, 5, 6, 7]
result = HHL_solve_linear_equations(A, b, 1)

#print HHL result
for key in result:
    print(key)
    
# 精确解 = [1, 1, 1, 1]
# Out:
# (0.9999999999999842+0j)
# (0.9999999999999799+0j)
# (0.9999999999999807+0j)
# (0.9999999999999869+0j)
