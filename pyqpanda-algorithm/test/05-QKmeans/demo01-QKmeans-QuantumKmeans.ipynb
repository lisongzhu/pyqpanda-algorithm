# %%
import sys
from pathlib import Path
sys.path.append((Path.cwd().parent.parent).__str__())

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
from pyqpanda_alg.QKmeans import QuantumKmeans
from pyqpanda_alg import QKmeans
from pyqpanda3.core import CPUQVM, QCircuit, QProg, TOFFOLI, X, Z, H, U1, RY
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24288/1725759130.py in <module>
#       4 from sklearn.cluster import KMeans
#       5 from sklearn.preprocessing import MinMaxScaler
# ----> 6 from pyqpanda_alg.QKmeans.QuantumKmeans import QuantumKmeans
#       7 from pyqpanda_alg import QKmeans
#       8 from pyqpanda3.core import CPUQVM, QCircuit, QProg, TOFFOLI, X, Z, H, U1, RY
#
# E:\pyqpanda-algorithm\pyqpanda-algorithm\pyqpanda_alg\__init__.py in <module>
#      29 # from . import QAOA
#      30 # from . import VQE
# ---> 31 from . import QARM
#      32 from . import QKmeans
#      33 # from . import QFinance
#
# E:\pyqpanda-algorithm\pyqpanda-algorithm\pyqpanda_alg\QARM\__init__.py in <module>
#      17 '''
#      18
# ---> 19 from . import qarm
#      20
#      21 __all__ = [qarm]
#
# E:\pyqpanda-algorithm\pyqpanda-algorithm\pyqpanda_alg\QARM\qarm.py in <module>
#       2 import math
#       3 import numpy as np
# ----> 4 from pyqpanda3.core import QCircuit, QProg, CPUQVM, X, H, U1, SWAP, draw_qprog
#       5 from pyqpanda3.intermediate_compiler import convert_qprog_to_originir
#       6 from pyqpanda3.qcloud import QCloudService
#
# ModuleNotFoundError: No module named 'pyqpanda3'

# %%
def ReadCSV(path):
    import csv
    csvFile = open(path, "r")
    reader = csv.reader(csvFile)
    data = []
    label = []
    for item in reader:
        data0 = []
        if reader.line_num == 1:
            continue
        for i in range(1, 5):
            data0.append(np.float64(item[i]))
        data.append(data0)
        label.append(item[5])
    csvFile.close()
    return np.array(data), label


if __name__ == '__main__':
    data_path = QKmeans.__path__[0]
    data_file = os.path.join(data_path, 'dataset/Iris.csv')
    data, label = ReadCSV(data_file)
    data = data[:, 2:]
    label = [i for i in label]
    for _ in range(len(label)):
        if label[_] == 'Iris-setosa':
            label[_] = 'r'
        elif label[_] == 'Iris-versicolor':
            label[_] = 'b'
        else:
            label[_] = 'g'
    rows, col = data.shape[0], data.shape[1]

    scaler = MinMaxScaler(feature_range=(-1, 1))
    data = scaler.fit_transform(data)

    n_clusters = 3
    Colors = ['black', 'blue', 'green', 'yellow', 'red', 'purple', 'orange', 'brown', 'pink']

    print('Classical K_means start...')
    Ctest = KMeans(n_clusters)
    Ctest.fit(data)
    Ccenter = Ctest.cluster_centers_
    print('Final Classical Result:', Ccenter)

    print('Quantum K_means start...')
    Qtest = QuantumKmeans(n_clusters)
    Qcenters, clusters = Qtest.fit(data)
    print('Final Quantum Result:', Qcenters)

    x0 = data[clusters == 0]
    x1 = data[clusters == 1]
    x2 = data[clusters == 2]
    plt.scatter(x0[:, 0], x0[:, 1], c="red", marker='o', label='label0')
    plt.scatter(x1[:, 0], x1[:, 1], c="green", marker='*', label='label1')
    plt.scatter(x2[:, 0], x2[:, 1], c="blue", marker='+', label='label2')

    plot_title = 'Iris Quantum K_means Result'
    plt.title(plot_title)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24288/2022961085.py in <module>
#      18
#      19 if __name__ == '__main__':
# ---> 20     data_path = QKmeans.__path__[0]
#      21     data_file = os.path.join(data_path, 'dataset/Iris.csv')
#      22     data, label = ReadCSV(data_file)
#
# NameError: name 'QKmeans' is not defined
