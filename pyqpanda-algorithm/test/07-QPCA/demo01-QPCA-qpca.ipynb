# %%
import sys
from pathlib import Path
sys.path.append((Path.cwd().parent.parent).__str__())

# %%
import numpy as np
from pyqpanda_alg.QPCA import qpca
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import numpy as np
# ----> 2 from pyqpanda_alg.QPCA.QPCA import qpca
#
# File E:\pyqpanda-algorithm\pyqpanda-algorithm\pyqpanda_alg\__init__.py:32
#      29 # from . import QAOA
#      30 # from . import VQE
#      31 from . import QARM
# ---> 32 from . import QKmeans
#      33 # from . import QFinance
#      34 # from . import QLuoShu
#      35 from . import QPCA
#
# File E:\pyqpanda-algorithm\pyqpanda-algorithm\pyqpanda_alg\QKmeans\__init__.py:9
#       1 '''
#       2 QKMeans (Quantum K-Means) is a quantum algorithm that is used for clustering data into k clusters,
#       3 where k is a user-specified parameter. It is an extension of the classical K-Means algorithm,
#       4 which is widely used in machine learning and data analysis.
#       5 QKMeans has the potential to provide speedup over classical K-Means when processing large datasets.
#       6 '''
# ----> 9 from . import QuantumKmeans
#      11 __all__ = [QuantumKmeans]
#
# File E:\pyqpanda-algorithm\pyqpanda-algorithm\pyqpanda_alg\QKmeans\QuantumKmeans.py:6
#       3 from numpy import pi
#       4 from pyqpanda3.core import CPUQVM, QCircuit, QProg, SWAP, U3, H, measure, draw_qprog
# ----> 6 from .. config import *
#       7 auth = Authorization()
#       9 def _QuantumKmeansCircuit(theta0, phi0, theta, phi):
#
# File E:\pyqpanda-algorithm\pyqpanda-algorithm\pyqpanda_alg\config.py:7
#       5 import requests
#       6 import subprocess
# ----> 7 from Crypto.Cipher import PKCS1_v1_5
#       8 from Crypto.PublicKey import RSA
#       9 import base64
#
# ModuleNotFoundError: No module named 'Crypto'

# %%
A = np.array([[-1, 2], [-2, -1], [-1, -2], [1, 3], [2, 1], [3, 2]])
data_q = qpca(A, 1)
print(data_q)
